# %%
import access_multiple_drives as acc
import pandas as pd
# %load_ext autoreload
# %autoreload 2
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
account1_creds = acc.auth(tokenFile = './token_zaher.json')
all_files_df=acc.list_drive_account_files(account1_creds,"pdfs")
all_files_df
# Out:
#                                     id                             name  \
# 0    17-b8MaFjbNq0Qw8nCg6XUnN62R0kS9WN               Copy of W8HNOR.pdf
# 1    1LvAAauXb-kA3md-dJPTF43J6jgaPH281    07-12 2018_20190101160443.pdf
# 2    1AXkbwk2Jht8sG32XENvBDvMa0iLg36ep  Lohn 12.2018_20190101160339.pdf
# 3    1WXFdpOcdjtWVv6SzDa7ZxkfFJJFG7S3Z  Lohn 11.2018_20190101160233.pdf
# 4    1WqRnOCldfCb-rPK3Pk7kKgb-Dj428ay9  Lohn 10.2018_20190101160101.pdf
# ..                                 ...                              ...
# 161       0Byh0T39H4GyTQ3VLSnRBQjNfRjQ               Git CheatSheet.pdf
# 162       0Byh0T39H4GyTOGdIcnIyQ1FJU1E  Spring Framework CheatSheet.pdf
# 163       0Byh0T39H4GyTeEFxb3FFQVM1NTg      Apache Camel CheatSheet.pdf
# 164       0Byh0T39H4GyTYlh4QmZSSjk3Mjg     ElasticSearch CheatSheet.pdf
# 165      0Byh0T39H4GyTc3RhcnRlcl9maWxl    How to get started with Drive
#
#             mimeType               createdTime              modifiedTime  \
# ...

# %%
duplicated_files_df=acc.get_duplicated_files_ids(all_files_df)
duplicated_files_df
# Out:
# [['1w7u6WKHglF3x5m8JlKPcjMoHAfWr55qZ', 'main_account'],
#  ['1P3z26cd9WAaTBKx7Exm8308mAfq-7O4U', 'main_account'],
#  ['17-b8MaFjbNq0Qw8nCg6XUnN62R0kS9WN', 'main_account'],
#  ['0ByGlM2CpCvOCeWxycWo5MGdTRWc', 'main_account'],
#  ['0ByGlM2CpCvOCanVMX2VyYmYxTWM', 'main_account'],
#  ['0ByGlM2CpCvOCTTRRZ3A0TXB2YTQ', 'main_account']]

# %%
acc.delete_file(account1_creds, '1VcRotQZkV2mBh6RKi-9y5gxOOZ_eLNfC')
